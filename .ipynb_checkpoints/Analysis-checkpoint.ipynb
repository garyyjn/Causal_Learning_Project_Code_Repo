# %%
import pandas as pd
import numpy as np
from data_loader import general_loader

# %%
combined_data = general_loader()

# %%
combined_data
# Out:
#     Overall rank Country or region  Score GDP per capita Social support  \
# 0              1           Finland  7.769          1.340          1.587
# 1              2           Denmark  7.600          1.383          1.573
# 2              3            Norway  7.554          1.488          1.582
# 3              4           Iceland  7.494          1.380          1.624
# 4              5       Netherlands  7.488          1.396          1.522
# ..           ...               ...    ...            ...            ...
# 123          147             Haiti  3.597          0.323          0.688
# 124          148          Botswana  3.488          1.041          1.145
# 125          150            Malawi  3.410          0.191          0.560
# 126          152            Rwanda  3.334          0.359          0.711
# 127          154       Afghanistan  3.203          0.350          0.517
#
#     Healthy life expectancy Freedom to make life choices Generosity  \
# 0                     0.986                        0.596      0.153
# 1                     0.996                        0.592      0.252
# 2                     1.028                        0.603      0.271
# 3                     1.026                        0.591      0.354
# 4                     0.999                        0.557      0.322
# ..                      ...                          ...        ...
# 123                   0.449                        0.026      0.419
# 124                   0.538                        0.455      0.025
# 125                   0.495                        0.443      0.218
# 126                   0.614                        0.555      0.217
# 127                   0.361                        0.000      0.158
#
#     Perceptions of corruption Country Name  ... Arable  Crops  Other Climate  \
# 0                       0.393      Finland  ...   7,19   0,03  92,78       3
# 1                       0.410      Denmark  ...  54,02   0,19  45,79       3
# 2                       0.341       Norway  ...   2,87      0  97,13       3
# 3                       0.118      Iceland  ...   0,07      0  99,93       3
# 4                       0.298  Netherlands  ...  26,71   0,97  72,32       3
# ..                        ...          ...  ...    ...    ...    ...     ...
# 123                     0.110        Haiti  ...   28,3  11,61  60,09       2
# 124                     0.100     Botswana  ...   0,65   0,01  99,34       1
# 125                     0.089       Malawi  ...  23,38   1,49  75,13       2
# 126                     0.411       Rwanda  ...  40,54  12,16   47,3       3
# 127                     0.025  Afghanistan  ...  12,13   0,22  87,65       1
#
#     Birthrate Deathrate Agriculture Industry Service average2002-2012
# 0       10,45      9,86       0,028    0,295   0,676         6.327259
# 1       11,13     10,36       0,018    0,246   0,735         8.029597
# 2       11,46       9,4       0,021    0,415   0,564         7.035733
# 3       13,64      6,72       0,086     0,15   0,765         7.019231
# 4        10,9      8,68       0,021    0,244   0,736         5.049087
# ..        ...       ...         ...      ...     ...              ...
# 123     36,44     12,17        0,28      0,2    0,52         3.090875
# 124     23,08      29,5       0,024    0,469   0,507         9.721000
# 125     43,13     19,33       0,342    0,158   0,499         4.690587
# 126     40,37     16,09       0,401    0,229    0,37         4.338375
# 127      46,6     20,34        0,38     0,24    0,38         3.325190
#
# [128 rows x 95 columns]

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 127
# Data columns (total 95 columns):
# Overall rank                    128 non-null object
# Country or region               128 non-null object
# Score                           128 non-null object
# GDP per capita                  128 non-null object
# Social support                  128 non-null object
# Healthy life expectancy         128 non-null object
# Freedom to make life choices    128 non-null object
# Generosity                      128 non-null object
# Perceptions of corruption       128 non-null object
# Country Name                    128 non-null object
# Country Code                    128 non-null object
# Indicator Name                  128 non-null object
# Indicator Code                  128 non-null object
# 1960                            0 non-null object
# 1961                            0 non-null object
# 1962                            0 non-null object
# 1963                            0 non-null object
# 1964                            0 non-null object
# 1965                            0 non-null object
# 1966                            0 non-null object
# 1967                            0 non-null object
# 1968                            0 non-null object
# 1969                            0 non-null object
# 1970                            21 non-null object
# 1971                            38 non-null object
# 1972                            34 non-null object
# 1973                            39 non-null object
# 1974                            38 non-null object
# 1975                            41 non-null object
# 1976                            39 non-null object
# 1977                            38 non-null object
# 1978                            38 non-null object
# 1979                            48 non-null object
# 1980                            51 non-null object
# 1981                            47 non-null object
# 1982                            49 non-null object
# 1983                            46 non-null object
# 1984                            47 non-null object
# 1985                            44 non-null object
# 1986                            48 non-null object
# 1987                            43 non-null object
# 1988                            42 non-null object
# 1989                            39 non-null object
# 1990                            37 non-null object
# 1991                            41 non-null object
# 1992                            42 non-null object
# 1993                            48 non-null object
# 1994                            53 non-null object
# 1995                            61 non-null object
# 1996                            61 non-null float64
# 1997                            28 non-null float64
# 1998                            63 non-null float64
# 1999                            81 non-null float64
# 2000                            86 non-null float64
# 2001                            83 non-null float64
# 2002                            84 non-null float64
# 2003                            76 non-null float64
# 2004                            86 non-null float64
# 2005                            79 non-null float64
# 2006                            76 non-null float64
# 2007                            80 non-null float64
# 2008                            88 non-null float64
# 2009                            84 non-null float64
# 2010                            89 non-null float64
# 2011                            91 non-null float64
# 2012                            89 non-null float64
# 2013                            92 non-null float64
# 2014                            85 non-null float64
# 2015                            80 non-null float64
# 2016                            81 non-null object
# 2017                            89 non-null object
# 2018                            43 non-null object
# 2019                            12 non-null object
# 2020                            0 non-null object
# Country                         128 non-null object
# Region                          128 non-null object
# Population                      128 non-null object
# Area                            128 non-null object
# Pop. Density                    128 non-null object
# Coastline                       128 non-null object
# Net migration                   128 non-null object
# Infant mortality                128 non-null object
# GDP                             128 non-null object
# Literacy                        128 non-null object
# Phones                          127 non-null object
# Arable                          128 non-null object
# Crops                           128 non-null object
# Other                           128 non-null object
# Climate                         115 non-null object
# Birthrate                       127 non-null object
# Deathrate                       127 non-null object
# Agriculture                     128 non-null object
# Industry                        128 non-null object
# Service                         128 non-null object
# average2002-2012                123 non-null float64
# dtypes: float64(21), object(74)
# memory usage: 96.0+ KB

# %%
region_list = combined_data['Region'].unique()
# Out:
# array(['WESTERN EUROPE                    ',
#        'OCEANIA                           ',
#        'NORTHERN AMERICA                  ', 'LATIN AMER. & CARIB   ',
#        'NEAR EAST                         ',
#        'EASTERN EUROPE                    ',
#        'ASIA (EX. NEAR EAST)        ', 'C.W. OF IND. STATES',
#        'BALTICS                           ',
#        'SUB-SAHARAN AFRICA                ',
#        'NORTHERN AFRICA                   '], dtype=object)

# %%
happiness_score_overall = combined_data['Score'].astype(float)
happiness_list = []
for region in region_list:
    happiness_index = combined_data[combined_data['Region']==region]['Score']
    happiness_list.append(happiness_index)

# %%
from scipy.stats import norm
mu_list = []
std_list = []
for i in range(11):
    mu, std = norm.fit(happiness_list[i].astype(float))
    mu_list.append(mu)
    std_list.append(std)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
plt.hist(happiness_score, bins = 14)
mu,std = norm.fit(happiness_score)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)*40
plt.plot(x, p, 'k', linewidth=2)


colors = ['b','g','r','c','m','y','k','w']
plt_list = []
for i in range(8):
    mu,std = norm.fit(happiness_list[i].astype(float))
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)*(std**.8)*20
    plt.plot(x, p, colors[i], linewidth=2, label = region_list[i])
    

plt.title('Distribution of Nationa Happiness Index')
plt.legend()

# %%
coastline = combined_data['Coastline']
area_coastline = []
for i in coastline:
    a = i.split(',')
    area_coastline.append(int(a[1]))
plt.hist(area_coastline, bins = 20)
#less than 9.8, more than 19.6
plt.title('coastline ratio distribution')
# Out:
# Text(0.5, 1.0, 'coastline ratio distribution')

# %%
combined_data["area_coastline"] = area_coastline
combined_data['area_coastline']
# Out:
# 0      37
# 1      97
# 2      77
# 3      83
# 4       9
#        ..
# 123    38
# 124     0
# 125     0
# 126     0
# 127     0
# Name: area_coastline, Length: 128, dtype: int64

# %%
combined_data['area_coastline'].median()
# Out:
# 20.0

# %%
happiness_lowcoastline = combined_data[combined_data['area_coastline'] <= 15.0]['Score']
happiness_highcoastline = combined_data[combined_data['area_coastline'] > 15.0]['Score']
plt.figure(figsize=(10,10))
plt.hist(happiness_score, bins = 14)
mu,std = norm.fit(happiness_score)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)*40
plt.plot(x, p, 'k', linewidth=2)


colors = ['b','g','r','c','m','y','k','w']

mu,std = norm.fit(happiness_lowcoastline.astype(float))
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)*(std**.8)*20
plt.plot(x, p, colors[0], linewidth=2, label = 'low coastline')

mu,std = norm.fit(happiness_highcoastline.astype(float))
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)*(std**.8)*20
plt.plot(x, p, colors[1], linewidth=2, label = 'high coastline')    

plt.title('Distribution of Nationa Happiness Index')
plt.legend()

# %%
investment = combined_data['average2002-2012']

plt.figure(figsize=(10,10))
plt.hist(investment, bins = 14)
# Out:
# C:\Users\gy\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\gy\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([12., 17., 20., 18., 18., 17., 13.,  5.,  0.,  1.,  0.,  1.,  0.,
#          1.]),
#  array([ 1.65821667,  2.34822569,  3.03823471,  3.72824373,  4.41825275,
#          5.10826177,  5.7982708 ,  6.48827982,  7.17828884,  7.86829786,
#          8.55830688,  9.24831591,  9.93832493, 10.62833395, 11.31834297]),
#  <a list of 14 Patch objects>)

# %%
combined_data['average2002-2012'].median()
# Out:
# 4.19777494675

# %%
historical_age = pd.read_csv('Data\\MedianAge.csv')
current_age = pd.read_csv('population_by_country_2020.csv')
